# %% [markdown]
# <a href="https://colab.research.google.com/github/Goutham345/AIML/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
print("LISTS")
a = [1, 2, 3, 4, 5]
print(a)
print("ARRAYS")
array1=np.array([6,7,8,9,5])
array2=np.array([1,2,3,4,5])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATION AND DIVISION OF ARRAYS")
mult_array = array1 * array2
print("Multiplication of array1 and array2:", mult_array)
div_array = array2 / array1
print("Division of array2 by array1:", div_array)
power_array = np.power(array1, 2)
print("Power of array1 elements:", power_array)
print("ADDITION OF ARRAYS")
add=array1+array2
print(add)
print("IMPLEMENTATIONS")

exp_array1 = np.exp(array1)
print("Exponential of array1:", exp_array1)

sin_array1 = np.sin(array1)
print("Sine of array1:", sin_array1)
print("LOG()")
result = np.log(array1)
print(result)
print("LOG2")
print(np.log2(array1))import numpy as np
import pandas as pd
print("LISTS")
a = [1, 2, 3, 4, 5]
print(a)
print("ARRAYS")
array1=np.array([6,7,8,9,5])
array2=np.array([1,2,3,4,5])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATION AND DIVISION OF ARRAYS")
mult_array = array1 * array2
print("Multiplication of array1 and array2:", mult_array)
div_array = array2 / array1
print("Division of array2 by array1:", div_array)
power_array = np.power(array1, 2)
print("Power of array1 elements:", power_array)
print("ADDITION OF ARRAYS")
add=array1+array2
print(add)
print("IMPLEMENTATIONS")

exp_array1 = np.exp(array1)
print("Exponential of array1:", exp_array1)

sin_array1 = np.sin(array1)
print("Sine of array1:", sin_array1)
print("LOG()")
result = np.log(array1)
print(result)
print("LOG2")
print(np.log2(array1))vimport numpy as np
import pandas as pd
print("LISTS")
a = [1, 2, 3, 4, 5]
print(a)
print("ARRAYS")
array1=np.array([6,7,8,9,5])
array2=np.array([1,2,3,4,5])
print(array1)
print(array2)
print("DATA TYPES")
print(type(array1))
print(type(array2))
print("MULTIPLICATION AND DIVISION OF ARRAYS")
mult_array = array1 * array2
print("Multiplication of array1 and array2:", mult_array)
div_array = array2 / array1
print("Division of array2 by array1:", div_array)
power_array = np.power(array1, 2)
print("Power of array1 elements:", power_array)
print("ADDITION OF ARRAYS")
add=array1+array2
print(add)
print("IMPLEMENTATIONS")

exp_array1 = np.exp(array1)
print("Exponential of array1:", exp_array1)

sin_array1 = np.sin(array1)
print("Sine of array1:", sin_array1)
print("LOG()")
result = np.log(array1)
print(result)
print("LOG2")
print(np.log2(array1))
